# %%
import pandas as pd

# %%
base = pd.read_csv('insect.csv')
base.shape
# Out:
# (72, 2)

# %%
base.tail()
# Out:
#     count spray
# 67     10     F
# 68     26     F
# 69     26     F
# 70     24     F
# 71     13     F

# %%
sprayGroup = base.groupby(['spray'])['count'].sum()
sprayGroup
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
sprayGroup.plot.bar(color='green')
# Out:
# <Axes: xlabel='spray'>

# %%
sprayGroup.plot.bar(color=['blue','green','red','yellow', 'pink', 'orange'])
# Out:
# <Axes: xlabel='spray'>

# %%
sprayGroup.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
sprayGroup.plot.pie(legend=True)
# Out:
# <Axes: ylabel='count'>
