# %%
import pandas as pd
import seaborn as sns

# %%
base = pd.read_csv('trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
sns.boxplot(data=base.Volume, orient='v', showfliers=False).set_title('Árvore')
# Out:
# Text(0.5, 1.0, 'Árvore')

# %%
sns.boxplot(data=base, showfliers=False)
# Out:
# <Axes: >
