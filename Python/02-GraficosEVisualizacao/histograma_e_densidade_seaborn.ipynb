# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
base =pd.read_csv('trees.csv')
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
sns.histplot(base.Volume, color='blue', kde=True, stat='density', bins=10).set(title='Volume')
# Out:
# [Text(0.5, 1.0, 'Volume')]

# %%
base2 = pd.read_csv('chicken.csv')
base2.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
feedgroup = base2.groupby(['feed'])['weight'].sum()
feedgroup
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
food = base2.loc[base2.feed == 'horsebean']
food
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean
# 5     168  horsebean
# 6     108  horsebean
# 7     124  horsebean
# 8     143  horsebean
# 9     140  horsebean

# %%
sns.kdeplot(base2.loc[base2.feed == 'horsebean'].weight).set(title='horsebean')
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
sns.histplot(base2.loc[base2.feed == 'casein'].weight, kde=True).set(title='casein')
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
sns.histplot(base2.loc[base2.feed == 'linseed'].weight, kde=True).set(title='linseed')
# Out:
# [Text(0.5, 1.0, 'linseed')]

# %%
sns.histplot(base2.loc[base2.feed == 'meatmeal'].weight).set(title='meatmeal')
# Out:
# [Text(0.5, 1.0, 'meatmeal')]

# %%
sns.histplot(base2.loc[base2.feed == 'soybean'].weight).set(title='soybean')
# Out:
# [Text(0.5, 1.0, 'soybean')]

# %%
sns.histplot(base2.loc[base2.feed == 'sunflower'].weight).set(title='sunflower')
# Out:
# [Text(0.5, 1.0, 'sunflower')]

# %%
plt.figure()
plt.subplot(3,2,1)
sns.histplot(base2.loc[base2.feed == 'horsebean'].weight, kde=True).set(title='horsebean')
plt.subplot(3, 2, 2)
sns.histplot(base2.loc[base2.feed == 'casein'].weight, kde=True).set(title='casein')
plt.subplot(3, 2, 3)
sns.histplot(base2.loc[base2.feed == 'linseed'].weight, kde=True).set(title='linseed')
plt.subplot(3, 2, 4)
sns.histplot(base2.loc[base2.feed == 'meatmeal'].weight, kde=True).set(title='meatmeal')
plt.subplot(3, 2, 5)
sns.histplot(base2.loc[base2.feed == 'soybean'].weight, kde=True).set(title='soybean')
plt.subplot(3, 2, 6)
sns.histplot(base2.loc[base2.feed == 'sunflower'].weight, kde=True).set(title='sunflower')
plt.tight_layout()
